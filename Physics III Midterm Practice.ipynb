# %% [markdown]
# # Physics III, Practice Midterm. Open book, notes, python.
#
# 1. How far is (1,2,3) from (4,5,6)?
#
#
# 2. How far is (1,2,3) from (-1,-2,-3)?
#
#
# 3. Two charges are separated by distance d. The force between them is proportional to $d^{-p}$. What is p?
#
#
# 4. A point charge is d away from a line of charge. The force on the point charge is proportional to $d^{-p}$. What is p?
#
#
# 5. A point charge is d away from a sheet of charge. The force on the point charge is proportional to $d^{-p}$. What is p?
#
#
# 6. What is the unit of force?
#
#
# 7. What is the unit of charge?
#
#
# 8. What is the unit of electric field?
#
#
# 9. What is a volt? 25 millivolts is how many volts?
#
#
# 10. What is an amp?  170 milliamps is how many amps.
#
#
# 11. If the current through a $20\ \mu F$ capacitor is $10\ mA$ what is the voltage drop across the capacitor?
#
#
# 12. Given two capacitors, $C_1=10\,\mu F$ and $C_2=100\,\mu F$, what is the effective capacitance if I place them in
#     (a) series,
#     (b) parallel.
#
#
# 13. 300 nanoFarads is how microFarads?

# %%
import matplotlib.pyplot as plt   
import schemdraw
import schemdraw.elements as elm

d = schemdraw.Drawing()

R0 = d.add(elm.RES, label='$R_0$')
d.labelI(R0, label='$I_0$', arrowofst=0.5, arrowlen=1.5, top=False)
node = d.add(elm.DOT)
node.add_label('$V_1$',loc = 'top')

R1 = d.add(elm.RES, label='$R_1$', d='down')
d.labelI(R1, label='$I_1$', arrowofst=1.2, arrowlen=1.5, top=True)

d.add(elm.LINE, d='left', tox = R0.start)
d.add(elm.GND)
d.add(elm.SOURCE_V, d='up', label='$V_0$')

node = d.add(elm.DOT)
node.add_label('$V_0$',loc = 'top') 

d.draw()

# %% [markdown]
# 14. In the circuit above, if $V_0=5\,V$ and $V_1=3\,V$ and $R_1=1\,k\Omega$ then what is $R_0$?
#
#
# 15. Given two resistors, $R_1=20\,k\Omega$ and $C_2=100\,k\Omega$, what is the effective resistance if I place them in
#     (a) series,
#     (b) parallel.
#
#
#
# 16. 22 $k\Omega$ is how many Ohms?
#
#
#
# 17. If the voltage drop across a resistor is 5 V, and the current through the resistor is 2 mA, what is the resistance?
#
#
#
# 18. Given $R=10\, k\Omega$ and $C=10\,\mu F$
#     (a) what is $RC$ is milliseconds
#     (b) what is the cutoff frequency of the $RC$ filter in hertz.
#
#
# 19. The unit of magnetic field is the Tesla. What is a Tesla in terms of more basic units?
#
#
# 20. If a postive charge is traveling in the direction (1,1,0) through a magnetic field in direction (1,-1,0) then what direction is the charge pushed?
#
#
# 21. If current is flowing in a wire along the direction (0,0,1) and feels a magnetic force in the direction (0,0,1) then which direction is the magnetic field acting.
