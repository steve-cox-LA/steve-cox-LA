# %% [markdown]
# # Physics III Final Practice
#
# Complete each problem, remaining in this notebook. Please tag each of your answers.
#
# You may consult only our textbook and our previous jupyter notebooks.

# %%
# let's draw and label our RLC circuit
import matplotlib.pyplot as plt   
import schemdraw
import schemdraw.elements as elm
d = schemdraw.Drawing()

R = d.add(elm.Resistor, label='$R$')
d.labelI(R, label='$I_R$', arrowofst=0.5, arrowlen=1.5, top=False)
node = d.add(elm.DOT)
node.add_label('$V_1$',loc = 'top') 

d.push()
C = d.add(elm.Capacitor, label='$C$', d='down')
d.labelI(C, label='$I_C$', arrowofst=1, arrowlen=1.5, top=True)

d.pop()
d.add(elm.LINE, d='right')

L = d.add(elm.Inductor, label='$L$', d='down')
d.labelI(L, label='$I_L$', arrowofst=1, arrowlen=1.5, top=True)

d.add(elm.LINE, d='left', tox = R.start)
d.add(elm.GND)
d.add(elm.SourceSin, d='up', label='$V_0$')

node = d.add(elm.DOT)
node.add_label('$V_0$',loc = 'top') 

d.draw()

# %% [markdown]
# 1. Express the resistor law for this $R$ and solve for $I_R$
#
#
#
# 2. Express the capacitor law for this $C$
#
#
#
# 3. Express the inductor law for this $L$ and solve for $I'_L$
#
#
#
# 4. Express Kirchhoff's Current Law for this circuit
#
#
#
# 5. Express the derivative of Kirchhoff's Current Law for this circuit
#
#
#
# 6. Use your answer to question (1) to express $I'_R$, your answer to question (3) to express $I'_C$, then substitute these and your $I'_L$ from question (3) into your answer for question (5) and arrive at a differential equation for $V_1$ in terms of $R$, $C$, $L$, and $V_0$. Please rearrange to place $V_0$ and $V_1$ terms on opposite sides and clean up as many denominators as is reasonable.
#
#
#
# 7. Insert
# $$
#   V_0(t) = A_0\cos(2\pi ft) \qquad\hbox{and}\qquad
#   V_1(t) = A_1\cos(2\pi ft - \phi)
# $$
#
#     into your answer to question (6) and arrive at a trigonometric equation.
#
#
# 8. Substitute $t=0$ into your trigonometric answer to question (7) and derive an expression for the phase shift $\phi$. Show all of your work, and justify, in English, each of your steps.
#
#
#
# 9. Substitute $t=1/(4f)$ into your trigonometric answer to question (7) and derive an expression for the amplitude, $A_1$, that does not depend on $\phi$. Show all of your work, and justify, in English, each of your steps.
#
#
#
# 10. With $L=100\, mH$, $C=100\,\mu F$ and $R=10\,\Omega$, graph your $A_1$ for $f$ between 0 and 100. Add a grid and carfully label both axes. Title your figure by the type of filter this is.
